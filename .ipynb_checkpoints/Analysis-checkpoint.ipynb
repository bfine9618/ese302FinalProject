# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error 

from sklearn.linear_model import Ridge, RidgeCV, Lasso, LassoCV
from sklearn.preprocessing import scale

import statsmodels.formula.api as smf

# %%
df = pd.read_csv('./baseball/core/Teams.csv')

# %%
df.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L     ...       \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10     ...
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9     ...
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19     ...
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12     ...
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17     ...
#
#    DP     FP                     name                          park  \
# 0 NaN  0.838     Boston Red Stockings           South End Grounds I
# 1 NaN  0.829  Chicago White Stockings       Union Base-Ball Grounds
# 2 NaN  0.814   Cleveland Forest Citys  National Association Grounds
# 3 NaN  0.803     Fort Wayne Kekiongas                Hamilton Field
# 4 NaN  0.839         New York Mutuals      Union Grounds (Brooklyn)
#
#    attendance  BPF  PPF  teamIDBR  teamIDlahman45  teamIDretro
# 0         NaN  103   98       BOS             BS1          BS1
# 1         NaN  104  102       CHI             CH1          CH1
# 2         NaN   96  100       CLE             CL1          CL1
# 3         NaN  101  107       KEK             FW1          FW1
# 4         NaN   90   88       NYU             NY2          NY2
#
# [5 rows x 48 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2835 entries, 0 to 2834
# Data columns (total 48 columns):
# yearID            2835 non-null int64
# lgID              2785 non-null object
# teamID            2835 non-null object
# franchID          2835 non-null object
# divID             1318 non-null object
# Rank              2835 non-null int64
# G                 2835 non-null int64
# Ghome             2436 non-null float64
# W                 2835 non-null int64
# L                 2835 non-null int64
# DivWin            1290 non-null object
# WCWin             654 non-null object
# LgWin             2807 non-null object
# WSWin             2478 non-null object
# R                 2835 non-null int64
# AB                2835 non-null int64
# H                 2835 non-null int64
# 2B                2835 non-null int64
# 3B                2835 non-null int64
# HR                2835 non-null int64
# BB                2835 non-null int64
# SO                2715 non-null float64
# SB                2691 non-null float64
# CS                1976 non-null float64
# HBP               510 non-null float64
# SF                510 non-null float64
# RA                2835 non-null int64
# ER                2835 non-null int64
# ERA               2835 non-null float64
# CG                2835 non-null int64
# SHO               2835 non-null int64
# SV                2835 non-null int64
# IPouts            2835 non-null int64
# HA                2835 non-null int64
# HRA               2835 non-null int64
# BBA               2835 non-null int64
# SOA               2835 non-null int64
# E                 2835 non-null int64
# DP                2518 non-null float64
# FP                2835 non-null float64
# name              2835 non-null object
# park              2801 non-null object
# attendance        2556 non-null float64
# BPF               2835 non-null int64
# PPF               2835 non-null int64
# teamIDBR          2835 non-null object
# teamIDlahman45    2835 non-null object
# teamIDretro       2835 non-null object
# dtypes: float64(10), int64(25), object(13)
# memory usage: 1.0+ MB

# %%
df = df[df["yearID"]>=1977]
df.drop('Rank', axis=1, inplace=True)
df.fillna(0, inplace=True)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1126 entries, 1709 to 2834
# Data columns (total 47 columns):
# yearID            1126 non-null int64
# lgID              1126 non-null object
# teamID            1126 non-null object
# franchID          1126 non-null object
# divID             1126 non-null object
# G                 1126 non-null int64
# Ghome             1126 non-null float64
# W                 1126 non-null int64
# L                 1126 non-null int64
# DivWin            1126 non-null object
# WCWin             1126 non-null object
# LgWin             1126 non-null object
# WSWin             1126 non-null object
# R                 1126 non-null int64
# AB                1126 non-null int64
# H                 1126 non-null int64
# 2B                1126 non-null int64
# 3B                1126 non-null int64
# HR                1126 non-null int64
# BB                1126 non-null int64
# SO                1126 non-null float64
# SB                1126 non-null float64
# CS                1126 non-null float64
# HBP               1126 non-null float64
# SF                1126 non-null float64
# RA                1126 non-null int64
# ER                1126 non-null int64
# ERA               1126 non-null float64
# CG                1126 non-null int64
# SHO               1126 non-null int64
# SV                1126 non-null int64
# IPouts            1126 non-null int64
# HA                1126 non-null int64
# HRA               1126 non-null int64
# BBA               1126 non-null int64
# SOA               1126 non-null int64
# E                 1126 non-null int64
# DP                1126 non-null float64
# FP                1126 non-null float64
# name              1126 non-null object
# park              1126 non-null object
# attendance        1126 non-null float64
# BPF               1126 non-null int64
# PPF               1126 non-null int64
# teamIDBR          1126 non-null object
# teamIDlahman45    1126 non-null object
# teamIDretro       1126 non-null object
# dtypes: float64(10), int64(24), object(13)
# memory usage: 422.2+ KB

# %%
def winPer(w, l):
    return w/(w+l)
df['winP'] = df.apply(lambda row : winPer(row['W'], row['L']), axis=1)

# %%
quant = pd.DataFrame(df.loc[:, ~(df.dtypes == object)])
quant.drop(['L'], axis=1, inplace=True)
quant.rename(columns={'2B':'doubles', '3B': 'triples'}, inplace=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(quant.drop(['winP', 'W'], axis=1), quant['W'], test_size=0.33, random_state=42)

# %%
train = pd.DataFrame(pd.concat([X_train, y_train], axis=1))
equation = "+".join(str(x) for x in quant.drop(['winP', 'W'], axis=1).columns)

# %%
linreg = smf.ols('W~'+equation, data=train).fit()
preds = linreg.predict(X_test)
linreg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      W   R-squared:                       0.945
# Model:                            OLS   Adj. R-squared:                  0.943
# Method:                 Least Squares   F-statistic:                     388.9
# Date:                Wed, 15 Nov 2017   Prob (F-statistic):               0.00
# Time:                        15:59:48   Log-Likelihood:                -1870.0
# No. Observations:                 754   AIC:                             3806.
# Df Residuals:                     721   BIC:                             3959.
# Df Model:                          32
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept    142.7036    264.856      0.539      0.590    -377.278     662.685
# yearID        -0.0136      0.037     -0.372      0.710      -0.085       0.058
# G             -0.0196      0.108     -0.181      0.857      -0.233       0.193
# Ghome          0.0304      0.119      0.254      0.799      -0.204       0.265
# R              0.0778      0.005     15.968      0.000       0.068       0.087
# AB            -0.0450      0.005     -9.969      0.000      -0.054      -0.036
# H              0.0384      0.005      7.155      0.000       0.028       0.049
# doubles       -0.0090      0.005     -1.658      0.098      -0.020       0.002
# triples       -0.0098      0.013     -0.737      0.461      -0.036       0.016
# HR             0.0194      0.007      2.871      0.004       0.006       0.033
# BB            -0.0015      0.003     -0.572      0.568      -0.007       0.004
# SO             0.0019      0.001      1.272      0.204      -0.001       0.005
# SB             0.0078      0.004      1.831      0.068      -0.001       0.016
# CS            -0.0454      0.012     -3.644      0.000      -0.070      -0.021
# HBP            0.0157      0.010      1.554      0.121      -0.004       0.036
# SF            -0.0007      0.014     -0.053      0.958      -0.027       0.026
# RA            -0.0264      0.012     -2.168      0.031      -0.050      -0.002
# ER            -0.0342      0.021     -1.619      0.106      -0.076       0.007
# ERA            2.5319      2.758      0.918      0.359      -2.883       7.946
# CG             0.1578      0.019      8.501      0.000       0.121       0.194
# SHO            0.1401      0.039      3.582      0.000       0.063       0.217
# SV             0.3522      0.020     17.395      0.000       0.312       0.392
# IPouts         0.0620      0.006     10.092      0.000       0.050       0.074
# HA            -0.0078      0.004     -2.191      0.029      -0.015      -0.001
# HRA           -0.0267      0.007     -3.674      0.000      -0.041      -0.012
# BBA           -0.0087      0.003     -3.098      0.002      -0.014      -0.003
# SOA           -0.0005      0.001     -0.314      0.754      -0.003       0.002
# E             -0.0547      0.042     -1.303      0.193      -0.137       0.028
# DP            -0.0051      0.008     -0.660      0.510      -0.020       0.010
# FP          -126.9598    257.764     -0.493      0.622    -633.018     379.099
# attendance  4.427e-07   2.07e-07      2.142      0.033    3.69e-08    8.48e-07
# BPF           -0.1108      0.178     -0.624      0.533      -0.459       0.238
# PPF            0.0919      0.175      0.524      0.600      -0.252       0.436
# ==============================================================================
# Omnibus:                        0.538   Durbin-Watson:                   1.877
# Prob(Omnibus):                  0.764   Jarque-Bera (JB):                0.430
# Skew:                           0.050   Prob(JB):                        0.807
# Kurtosis:                       3.062   Cond. No.                     7.74e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.74e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
mseOLS = mean_squared_error(y_test, preds)
print('Test MSE: ' + str(mseOLS))
# Out:
# Test MSE: 8.70201891163

# %%
lasso = Lasso(max_iter=10000, normalize=True)
alphas = 10**np.linspace(10, -5, 100) * 0.5

coeffs = []

for a in alphas:
    lasso.set_params(alpha = a)
    lasso.fit(scale(X_train), y_train)
    coeffs.append(lasso.coef_)
    
ax = plt.gca()
ax.plot(alphas * 2, coeffs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')

plt.show()

# %%
lassocv = LassoCV(alphas=None, cv=10, max_iter=100000, normalize=True)
lassocv.fit(X_train, y_train)

lasso.set_params(alpha=lassocv.alpha_)
lasso.fit(X_train, y_train)
mseLasso = mean_squared_error(y_test, lasso.predict(X_test))
print(pd.Series(lasso.coef_, index=X_test.columns))
print('Lasso Test MSE: ' + str(mseLasso))
# Out:
# yearID       -0.000000e+00
# G            -0.000000e+00
# Ghome         3.233054e-02
# R             7.908345e-02
# AB           -3.469617e-02
# H             2.848686e-02
# doubles      -7.957369e-03
# triples      -7.661514e-03
# HR            1.752223e-02
# BB            1.636732e-04
# SO            9.137350e-04
# SB            5.965555e-03
# CS           -3.027177e-02
# HBP           1.539973e-02
# SF            0.000000e+00
# RA           -3.132322e-02
# ER           -1.699786e-02
# ERA          -0.000000e+00
# CG            1.629114e-01
# SHO           1.443522e-01
# SV            3.627380e-01
# IPouts        4.777618e-02
# HA           -6.136454e-03
# HRA          -2.519225e-02
# BBA          -7.635477e-03
# SOA           0.000000e+00
# E            -3.191805e-02
# DP           -5.321598e-03
# FP            0.000000e+00
# attendance    4.832733e-07
# BPF          -1.383427e-02
# PPF          -0.000000e+00
# dtype: float64
# Lasso Test MSE: 8.6862336501

# %%
ridge = Ridge(normalize=True)
coeffs = []

for a in alphas:
    ridge.set_params(alpha=a)
    ridge.fit(X_test, y_test)
    coeffs.append(ridge.coef_)
    
np.shape(coeffs)
ax = plt.gca()
ax.plot(alphas, coeffs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')
plt.show()

# %%
ridge2 = RidgeCV(alphas=range(-2,10), cv=10, normalize=True)
ridge2.fit(X_train, y_train)
pred2 = ridge2.predict(X_test)
mseRidge = mean_squared_error(y_test, pred2)
print (pd.Series(ridge2.coef_, index=X_test.columns))
print ('Ridge Test MSE: ' + str(mseRidge))
# Out:
# yearID       -1.360639e-02
# G            -1.958988e-02
# Ghome         3.039373e-02
# R             7.784780e-02
# AB           -4.498381e-02
# H             3.841008e-02
# doubles      -9.025026e-03
# triples      -9.843823e-03
# HR            1.943277e-02
# BB           -1.531503e-03
# SO            1.885243e-03
# SB            7.781069e-03
# CS           -4.541202e-02
# HBP           1.571587e-02
# SF           -7.195933e-04
# RA           -2.638960e-02
# ER           -3.416815e-02
# ERA           2.531860e+00
# CG            1.577693e-01
# SHO           1.401012e-01
# SV            3.521725e-01
# IPouts        6.204138e-02
# HA           -7.763639e-03
# HRA          -2.669322e-02
# BBA          -8.703601e-03
# SOA          -4.690400e-04
# E            -5.471391e-02
# DP           -5.076946e-03
# FP           -1.269598e+02
# attendance    4.426878e-07
# BPF          -1.107520e-01
# PPF           9.187922e-02
# dtype: float64
# Ridge Test MSE: 8.70201891163

# %%
best = min(mseOLS, mseLasso, mseRidge)
print('# Betas in OLS: ' + str(len(linreg.params)))
print('OLS Test MSE: {:,.6f}'.format(mseOLS) + ', ' 
      + str((np.round(mseOLS/best, 4) - 1)*100) + "% delta from best MSE")
print('Ridge Test MSE: {:,.6f}'.format(mseRidge) 
      + ', ' + str((np.round(mseRidge/best, 4) - 1)*100) + "% delta from best MSE")
print('Lasso Test MSE: {:,.6f}'.format(mseLasso)
      + ', ' + str((np.round(mseLasso/best, 4) - 1)*100) + "% delta from best MSE")
print('Lasso Betas <> 0: ' + str(len(lasso.coef_[lasso.coef_ != 0])))
print('Lasso Betas ~<> 0 (10^-4): ' + str(len(lasso.coef_[np.abs(lasso.coef_) > 0.0001])))
# Out:
# # Betas in OLS: 33
# OLS Test MSE: 8.702019, 0.18% delta from best MSE
# Ridge Test MSE: 8.702019, 0.18% delta from best MSE
# Lasso Test MSE: 8.686234, 0.0% delta from best MSE
# Lasso Betas <> 0: 25
# Lasso Betas ~<> 0 (10^-4): 24

# %%
lsb = pd.DataFrame(lasso.coef_, index=X_test.columns, columns=['Betas'])
lsb = lsb[np.abs(lsb['Betas']) > 0.0001]
print(lsb)
# Out:
#                Betas
# Ghome       0.032331
# R           0.079083
# AB         -0.034696
# H           0.028487
# secondBase -0.007957
# thirdBase  -0.007662
# HR          0.017522
# BB          0.000164
# SO          0.000914
# SB          0.005966
# CS         -0.030272
# HBP         0.015400
# RA         -0.031323
# ER         -0.016998
# CG          0.162911
# SHO         0.144352
# SV          0.362738
# IPouts      0.047776
# HA         -0.006136
# HRA        -0.025192
# BBA        -0.007635
# E          -0.031918
# DP         -0.005322
# BPF        -0.013834

# %%
cols = quant.drop(['winP', 'W'], axis=1).columns

# %%
train = pd.DataFrame(pd.concat([X_train, y_train], axis=1))
equation = "+".join(str(x) for x in quant.drop(['winP', 'W'], axis=1).columns) 
mse = []

cols[0:0]
for i in range(1,len(cols)):
    equation = "+".join(str(x) for x in cols[0:i])
    linreg = smf.ols('W~'+equation, data=train).fit()
    preds = linreg.predict(X_test)
    mse.append(mean_squared_error(y_test, preds))

# %%
fig, ax = plt.subplots(1,1) 
ax.plot(mse)
ax.set_xticks(range(0,len(cols)))
ax.set_xticklabels(cols.values, rotation='vertical', fontsize=12)
fig.savefig('forwardSelectionMSE.png')

# %%
cols = quant.drop(['winP', 'W', 'RA', 'ER'], axis=1).columns

train = pd.DataFrame(pd.concat([X_train, y_train], axis=1))
equation = "+".join(str(x) for x in quant.drop(['winP', 'W'], axis=1).columns) 
mse = []

cols[0:0]
for i in range(1,len(cols)):
    equation = "+".join(str(x) for x in cols[0:i])
    linreg = smf.ols('W~'+equation, data=train).fit()
    preds = linreg.predict(X_test)
    mse.append(mean_squared_error(y_test, preds))
    
fig, ax = plt.subplots(1,1) 
ax.plot(mse)
ax.set_xticks(range(0,len(cols)))
ax.set_xticklabels(cols.values, rotation='vertical', fontsize=12)
fig.savefig('forwardSelectionMSE.png')

# %%
equation = "+".join(str(x) for x in quant.iloc[:,0:16].columns) 
equation
# Out:
# 'yearID+G+Ghome+W+R+AB+H+doubles+triples+HR+BB+SO+SB+CS+HBP+SF'

# %%
train = pd.DataFrame(pd.concat([X_train, y_train], axis=1))
equation = "+".join(str(x) for x in quant.drop(['winP', 'W'], axis=1).iloc[:,0:15].columns) 
linreg = smf.ols('W~'+equation, data=train).fit()
preds = linreg.predict(X_test)
linreg.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                      W   R-squared:                       0.478
# Model:                            OLS   Adj. R-squared:                  0.467
# Method:                 Least Squares   F-statistic:                     45.01
# Date:                Wed, 15 Nov 2017   Prob (F-statistic):           1.80e-93
# Time:                        16:06:09   Log-Likelihood:                -2720.2
# No. Observations:                 754   AIC:                             5472.
# Df Residuals:                     738   BIC:                             5546.
# Df Model:                          15
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept   -203.3501    155.808     -1.305      0.192    -509.230     102.529
# yearID         0.1023      0.078      1.307      0.192      -0.051       0.256
# G              1.4016      0.293      4.778      0.000       0.826       1.977
# Ghome          0.0694      0.352      0.197      0.844      -0.621       0.760
# R              0.0603      0.014      4.182      0.000       0.032       0.089
# AB            -0.0422      0.009     -4.851      0.000      -0.059      -0.025
# H              0.0318      0.014      2.273      0.023       0.004       0.059
# doubles       -0.0477      0.016     -2.947      0.003      -0.079      -0.016
# triples        0.0084      0.040      0.209      0.834      -0.070       0.087
# HR             0.0106      0.019      0.548      0.584      -0.027       0.049
# BB             0.0249      0.007      3.379      0.001       0.010       0.039
# SO            -0.0118      0.004     -2.750      0.006      -0.020      -0.003
# SB             0.0487      0.013      3.888      0.000       0.024       0.073
# CS            -0.1039      0.035     -3.013      0.003      -0.172      -0.036
# HBP            0.0749      0.031      2.452      0.014       0.015       0.135
# SF            -0.0750      0.041     -1.848      0.065      -0.155       0.005
# ==============================================================================
# Omnibus:                        3.030   Durbin-Watson:                   1.903
# Prob(Omnibus):                  0.220   Jarque-Bera (JB):                2.534
# Skew:                          -0.020   Prob(JB):                        0.282
# Kurtosis:                       2.719   Cond. No.                     2.91e+06
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.91e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
mseOLS = mean_squared_error(y_test, preds)
print(mseOLS)
# Out:
# 78.506311975

# %%
X_train, X_test, y_train, y_test = train_test_split(
    quant.drop(['winP', 'W'], axis=1).iloc[:,0:16], quant['W'], test_size=0.33, random_state=42)

# %%
lasso = Lasso(max_iter=10000, normalize=True)
alphas = 10**np.linspace(10, -5, 100) * 0.5

coeffs = []

for a in alphas:
    lasso.set_params(alpha = a)
    lasso.fit(scale(X_train), y_train)
    coeffs.append(lasso.coef_)
    
ax = plt.gca()
ax.plot(alphas * 2, coeffs)
ax.set_xscale('log')
plt.axis('tight')
plt.xlabel('alpha')
plt.ylabel('weights')

plt.show()

# %%
lassocv = LassoCV(alphas=None, cv=10, max_iter=100000, normalize=True)
lassocv.fit(X_train, y_train)

lasso.set_params(alpha=lassocv.alpha_)
lasso.fit(X_train, y_train)
mseLasso = mean_squared_error(y_test, lasso.predict(X_test))
print(pd.Series(lasso.coef_, index=X_test.columns))
print('Lasso Test MSE: ' + str(mseLasso))
# Out:
# yearID    -0.000000
# G          0.668223
# Ghome      0.281055
# R          0.081825
# AB        -0.013189
# H          0.021598
# doubles   -0.007183
# triples   -0.019110
# HR         0.028462
# BB         0.008917
# SO        -0.001001
# SB         0.012686
# CS        -0.013472
# HBP        0.020024
# SF        -0.020539
# RA        -0.102650
# dtype: float64
# Lasso Test MSE: 15.0887341648

# %%
ridge2 = RidgeCV(alphas=range(-2,10), cv=10, normalize=True)
ridge2.fit(X_train, y_train)
pred2 = ridge2.predict(X_test)
mseRidge = mean_squared_error(y_test, pred2)
print (pd.Series(ridge2.coef_, index=X_test.columns))
print ('Ridge Test MSE: ' + str(mseRidge))
# Out:
# yearID    -0.002679
# G          0.772784
# Ghome      0.280480
# R          0.080369
# AB        -0.017286
# H          0.026308
# doubles   -0.007960
# triples   -0.020080
# HR         0.029767
# BB         0.008827
# SO        -0.000730
# SB         0.014152
# CS        -0.019895
# HBP        0.024235
# SF        -0.026722
# RA        -0.102499
# dtype: float64
# Ridge Test MSE: 15.0839386208

# %%
best = min(mseOLS, mseLasso, mseRidge)
print('# Betas in OLS: ' + str(len(linreg.params)))
print('OLS Test MSE: {:,.6f}'.format(mseOLS) + ', ' 
      + str((np.round(mseOLS/best, 4) - 1)*100) + "% delta from best MSE")
print('Ridge Test MSE: {:,.6f}'.format(mseRidge) 
      + ', ' + str((np.round(mseRidge/best, 4) - 1)*100) + "% delta from best MSE")
print('Lasso Test MSE: {:,.6f}'.format(mseLasso)
      + ', ' + str((np.round(mseLasso/best, 4) - 1)*100) + "% delta from best MSE")
print('Lasso Betas <> 0: ' + str(len(lasso.coef_[lasso.coef_ != 0])))
print('Lasso Betas ~<> 0 (10^-4): ' + str(len(lasso.coef_[np.abs(lasso.coef_) > 0.0001])))
# Out:
# # Betas in OLS: 16
# OLS Test MSE: 78.506312, 420.46% delta from best MSE
# Ridge Test MSE: 15.083939, 0.0% delta from best MSE
# Lasso Test MSE: 15.088734, 0.03% delta from best MSE
# Lasso Betas <> 0: 15
# Lasso Betas ~<> 0 (10^-4): 15

# %%
import seaborn as sns
sns.set_context('poster')

# %%
train.corr()
# Out:
#               yearID         G     Ghome         R        AB         H  \
# yearID      1.000000  0.213940  0.212322  0.214376  0.227072  0.154465
# G           0.213940  1.000000  0.985877  0.527186  0.979124  0.777787
# Ghome       0.212322  0.985877  1.000000  0.525946  0.965920  0.770625
# R           0.214376  0.527186  0.525946  1.000000  0.624757  0.839339
# AB          0.227072  0.979124  0.965920  0.624757  1.000000  0.867714
# H           0.154465  0.777787  0.770625  0.839339  0.867714  1.000000
# doubles     0.509817  0.524631  0.518921  0.719768  0.608112  0.721596
# triples    -0.246849  0.162598  0.163232  0.086610  0.176220  0.223087
# HR          0.429319  0.346616  0.344898  0.756505  0.412106  0.499007
# BB          0.032807  0.457198  0.454256  0.664038  0.466017  0.493715
# SO          0.782540  0.480126  0.473248  0.271576  0.462563  0.238489
# SB         -0.262184  0.126128  0.121364 -0.013040  0.090817  0.037655
# CS         -0.570887  0.082423  0.073415 -0.134513  0.029542 -0.010874
# HBP         0.793807  0.226418  0.222349  0.245299  0.240966  0.195083
# SF          0.802686  0.231918  0.228265  0.270700  0.250458  0.228012
# RA          0.205343  0.505447  0.502217  0.510294  0.557092  0.565588
# ER          0.282220  0.493443  0.490622  0.531454  0.549589  0.570442
# ERA         0.216805  0.048706  0.054993  0.327617  0.117391  0.243202
# CG         -0.768817 -0.021448 -0.017035 -0.127746 -0.044656 -0.029958
# SHO         0.025009  0.200306  0.196679 -0.051081  0.155030  0.058129
# SV          0.306803  0.336108  0.330643  0.307220  0.328732  0.303169
# IPouts      0.193129  0.991256  0.977729  0.520941  0.977822  0.773473
# HA          0.146803  0.749230  0.742410  0.549667  0.782704  0.725047
# HRA         0.492794  0.405195  0.404270  0.545658  0.455752  0.475049
# BBA         0.033861  0.471864  0.465114  0.318673  0.483516  0.406365
# SOA         0.779739  0.479618  0.473837  0.331193  0.478345  0.344826
# E          -0.559279  0.274424  0.265075 -0.035572  0.247097  0.142569
# DP          0.005080  0.462034  0.453679  0.358610  0.487527  0.477372
# FP          0.618339  0.085714  0.089326  0.228374  0.108013  0.143801
# attendance  0.410124  0.242118  0.253353  0.435217  0.269577  0.352394
# BPF         0.023954 -0.016079 -0.011696  0.218076  0.021484  0.166314
# PPF         0.023688 -0.016179 -0.012042  0.149305  0.014522  0.126521
# W           0.089703  0.450170  0.449195  0.618466  0.469294  0.548372
#
#              doubles   triples        HR        BB    ...          HRA  \
# yearID      0.509817 -0.246849  0.429319  0.032807    ...     0.492794
# G           0.524631  0.162598  0.346616  0.457198    ...     0.405195
# Ghome       0.518921  0.163232  0.344898  0.454256    ...     0.404270
# R           0.719768  0.086610  0.756505  0.664038    ...     0.545658
# AB          0.608112  0.176220  0.412106  0.466017    ...     0.455752
# H           0.721596  0.223087  0.499007  0.493715    ...     0.475049
# doubles     1.000000  0.050756  0.551055  0.398985    ...     0.544261
# triples     0.050756  1.000000 -0.200315 -0.042596    ...    -0.078262
# HR          0.551055 -0.200315  1.000000  0.444841    ...     0.605465
# BB          0.398985 -0.042596  0.444841  1.000000    ...     0.262871
# SO          0.461654 -0.136842  0.504181  0.230758    ...     0.492415
# SB         -0.164079  0.297694 -0.230028  0.053750    ...    -0.130947
# CS         -0.330723  0.294192 -0.350089 -0.006573    ...    -0.253805
# HBP         0.503356 -0.148721  0.423167  0.040985    ...     0.446581
# SF          0.525971 -0.112805  0.407374  0.064691    ...     0.464219
# RA          0.497828  0.056974  0.426539  0.282863    ...     0.768319
# ER          0.535879  0.029211  0.462871  0.285281    ...     0.806696
# ERA         0.337110 -0.049610  0.343228  0.082349    ...     0.712941
# CG         -0.371245  0.224871 -0.287470  0.002490    ...    -0.393519
# SHO        -0.009699  0.040918 -0.100727  0.048564    ...    -0.349607
# SV          0.292397 -0.038380  0.254352  0.252079    ...     0.033356
# IPouts      0.510628  0.165115  0.333828  0.468246    ...     0.356508
# HA          0.526222  0.129187  0.368991  0.358509    ...     0.601387
# HRA         0.544261 -0.078262  0.605465  0.262871    ...     1.000000
# BBA         0.284738  0.072409  0.237260  0.299173    ...     0.434895
# SOA         0.520668 -0.167286  0.468721  0.244178    ...     0.391705
# E          -0.173056  0.249039 -0.207475  0.039394    ...    -0.140959
# DP          0.300660  0.123795  0.204537  0.215848    ...     0.272008
# FP          0.360458 -0.181751  0.326298  0.135649    ...     0.252275
# attendance  0.355111 -0.115647  0.426954  0.323251    ...     0.155403
# BPF         0.181498  0.162398  0.181127 -0.012653    ...     0.131488
# PPF         0.150919  0.160527  0.131933 -0.069787    ...     0.166976
# W           0.381622  0.071270  0.425128  0.528146    ...    -0.042116
#
#                  BBA       SOA         E        DP        FP  attendance  \
# yearID      0.033861  0.779739 -0.559279  0.005080  0.618339    0.410124
# G           0.471864  0.479618  0.274424  0.462034  0.085714    0.242118
# Ghome       0.465114  0.473837  0.265075  0.453679  0.089326    0.253353
# R           0.318673  0.331193 -0.035572  0.358610  0.228374    0.435217
# AB          0.483516  0.478345  0.247097  0.487527  0.108013    0.269577
# H           0.406365  0.344826  0.142569  0.477372  0.143801    0.352394
# doubles     0.284738  0.520668 -0.173056  0.300660  0.360458    0.355111
# triples     0.072409 -0.167286  0.249039  0.123795 -0.181751   -0.115647
# HR          0.237260  0.468721 -0.207475  0.204537  0.326298    0.426954
# BB          0.299173  0.244178  0.039394  0.215848  0.135649    0.323251
# SO          0.240141  0.771450 -0.215855  0.089865  0.370899    0.273754
# SB          0.054104 -0.137540  0.289855 -0.035796 -0.238800   -0.090891
# CS          0.081181 -0.379147  0.486493  0.060476 -0.441831   -0.292037
# HBP         0.021004  0.596664 -0.441981  0.075996  0.510360    0.328282
# SF          0.025192  0.597481 -0.458478  0.069950  0.527442    0.351911
# RA          0.674067  0.148103  0.248522  0.434814 -0.102772   -0.032415
# ER          0.653861  0.194828  0.124990  0.429039  0.019324    0.018936
# ERA         0.504277 -0.025025  0.003607  0.248584 -0.027000   -0.100521
# CG         -0.097353 -0.548537  0.420957  0.052504 -0.410054   -0.283275
# SHO        -0.254412  0.225492 -0.100997 -0.058719  0.196447    0.239219
# SV         -0.049741  0.413219 -0.175831  0.048750  0.311823    0.404647
# IPouts      0.440191  0.484196  0.271514  0.451506  0.092800    0.254458
# HA          0.519153  0.175222  0.324128  0.586012 -0.064997    0.054412
# HRA         0.434895  0.391705 -0.140959  0.272008  0.252275    0.155403
# BBA         1.000000  0.161282  0.278105  0.338962 -0.138831   -0.040289
# SOA         0.161282  1.000000 -0.327438 -0.071190  0.481944    0.461887
# E           0.278105 -0.327438  1.000000  0.154903 -0.923622   -0.337281
# DP          0.338962 -0.071190  0.154903  1.000000  0.047286    0.019299
# FP         -0.138831  0.481944 -0.923622  0.047286  1.000000    0.441277
# attendance -0.040289  0.461887 -0.337281  0.019299  0.441277    1.000000
# BPF        -0.023153 -0.004844 -0.062627  0.065247  0.066037    0.138709
# PPF         0.037901 -0.036837 -0.016297  0.080093  0.012130    0.047027
# W          -0.116606  0.359894 -0.130592  0.123037  0.327738    0.530117
#
#                  BPF       PPF         W
# yearID      0.023954  0.023688  0.089703
# G          -0.016079 -0.016179  0.450170
# Ghome      -0.011696 -0.012042  0.449195
# R           0.218076  0.149305  0.618466
# AB          0.021484  0.014522  0.469294
# H           0.166314  0.126521  0.548372
# doubles     0.181498  0.150919  0.381622
# triples     0.162398  0.160527  0.071270
# HR          0.181127  0.131933  0.425128
# BB         -0.012653 -0.069787  0.528146
# SO         -0.006556  0.009714  0.148111
# SB         -0.053417 -0.058520  0.113482
# CS         -0.041506 -0.023506 -0.009674
# HBP         0.025859  0.020610  0.138452
# SF          0.049073  0.041499  0.140527
# RA          0.143607  0.220002 -0.213193
# ER          0.154772  0.225883 -0.190516
# ERA         0.190085  0.273317 -0.459315
# CG         -0.051377 -0.071509  0.079092
# SHO        -0.140978 -0.208614  0.482944
# SV         -0.019128 -0.077688  0.626364
# IPouts     -0.033980 -0.042404  0.498987
# HA          0.112591  0.164725  0.053678
# HRA         0.131488  0.166976 -0.042116
# BBA        -0.023153  0.037901 -0.116606
# SOA        -0.004844 -0.036837  0.359894
# E          -0.062627 -0.016297 -0.130592
# DP          0.065247  0.080093  0.123037
# FP          0.066037  0.012130  0.327738
# attendance  0.138709  0.047027  0.530117
# BPF         1.000000  0.980831  0.037615
# PPF         0.980831  1.000000 -0.086152
# W           0.037615 -0.086152  1.000000
#
# [33 rows x 33 columns]

# %% [markdown]
# varience inflation for multiple colinarity, autocorrelation,
